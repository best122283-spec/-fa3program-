# %% [markdown]
# <a href="https://colab.research.google.com/github/best122283-spec/-fa3program-/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fa3prog1
user=input("hi! whats your name?")#ask their name first
age=input("age?")#then ask for their age
student_course=input("course?")#ask for their course
print(f"\n--- Student Information ---")
print(f"Name: {user}")
print(f"Age: {age}")
print(f"Course: {student_course}")
print(f"---------------------------")
# Out:
# hi! whats your name?johan
# age?13
# course?comsci
#
# --- Student Information ---
# Name: johan
# Age: 13
# Course: comsci
# ---------------------------

# %%
#faprog2
examscore=int(input("hi! may i ask what your score is?"))#ask for their score and convert to integer
if examscore >=75:
    print("you passed, yehey!")
else:
    print("you failed, ohno!")
# Out:
# hi! may i ask what your score is?99
# you passed, yehey!

# %%
#faprog3
user=input("name?")
score=int(input("score?"))
if score >=90:
  print("you got an A, woohoo!")
elif score <90 and score >=80:
  print("you got a B, great job!")
elif score <80 and score >=70:
  print("you got a C, nice!")
else:
  print("you got an F, OH NO!")
# Out:
# name?76
# score?76
# you got a C, nice!
